# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('datosfiltrados.csv', header = 0)
#data = data.dropna() ##Dropping NA fields

print(data.shape)
print(list(data.columns))
# Out:
# (17687, 20)
# ['Unnamed: 0', 'Unnamed: 0.1', 'danho', 'ciclo', 'Cod.Asign', 'Asignatura', 'Cod.Car.Sec', 'Cod.Curso', 'Convocatoria', 'Anho', 'Semestre', 'Aprobado', 'Anho.Firma', 'Primer.Par', 'Segundo.Par', 'AOT', 'Primer.Rec', 'Segundo.Rec', 'Nota.Final', 'id_anony']

# %%
data
# Out:
#        Unnamed: 0  Unnamed: 0.1  danho  ciclo  Cod.Asign Asignatura  \
# 0          135020           503   2017      1      13008  CALCULO 2
# 1          135021           504   2017      1      13008  CALCULO 2
# 2          135022           505   2017      1      13008  CALCULO 2
# 3          135023           506   2017      1      13008  CALCULO 2
# 4          135024           507   2017      1      13008  CALCULO 2
# ...           ...           ...    ...    ...        ...        ...
# 17682      206744          6959   2019      2      13018   DINAMICA
# 17683      206745          6960   2019      2      13018   DINAMICA
# 17684      206746          6961   2019      2      13018   DINAMICA
# 17685      206747          6962   2019      2      13018   DINAMICA
# 17686      206748          6963   2019      2      13018   DINAMICA
#
#       Cod.Car.Sec  Cod.Curso  Convocatoria  Anho  Semestre Aprobado  \
# 0      ELE-PLS13           2             1  2017         1        N
# ...

# %%
data.dtypes
# Out:
# Unnamed: 0       int64
# Unnamed: 0.1     int64
# danho            int64
# ciclo            int64
# Cod.Asign        int64
# Asignatura      object
# Cod.Car.Sec     object
# Cod.Curso        int64
# Convocatoria     int64
# Anho             int64
# Semestre         int64
# Aprobado        object
# Anho.Firma       int64
# Primer.Par       int64
# Segundo.Par      int64
# AOT              int64
# Primer.Rec       int64
# Segundo.Rec      int64
# Nota.Final      object
# id_anony        object
# dtype: object

# %%
newdf=data[data['Asignatura']=='ESTATICA']

# %%
ndf=newdf.drop(columns=['Unnamed: 0','Unnamed: 0.1','ciclo','Cod.Asign','Asignatura','Cod.Curso','Convocatoria','Anho','id_anony','danho','Semestre'])

# %%
import seaborn as sns

# %%
ndf=newdf.drop(columns=['Unnamed: 0','Unnamed: 0.1','ciclo','Cod.Asign','Asignatura','Cod.Curso','Convocatoria','Anho','id_anony','danho','Semestre'])

# %%
# Out:
#       Cod.Car.Sec Aprobado  Anho.Firma  Primer.Par  Segundo.Par  AOT  \
# 4455   CIV-PLS13         N           0           7            0    0
# 4456   MCT-PLS13         S        2017          18           15    0
# 4457   CIV-PLS13         N           0          13            0    0
# 4458   CIV-PLS13         N           0           0            0    0
# 4459   IND-PLS13         N           0           4            8    0
# ...           ...      ...         ...         ...          ...  ...
# 17432  CIV-PLS13         N           0           9           11    3
# 17433  CIV-PLS13         N        2019          12           20    3
# 17434  CIV-PLS13         N           0           0            0    2
# 17435  CIV-PLS13         S        2019          22           26    8
# 17436  CIV-PLS13         N        2019           9           22    5
#
#        Primer.Rec  Segundo.Rec Nota.Final
# 4455            0            0        NaN
# 4456            0            0       1F-2
# ...

# %%
ndf.to_csv('DatosfiltradosII.csv')

# %%
ndf.dtypes
# Out:
# Cod.Car.Sec    object
# Aprobado       object
# Anho.Firma      int64
# Primer.Par      int64
# Segundo.Par     int64
# AOT             int64
# Primer.Rec      int64
# Segundo.Rec     int64
# Nota.Final     object
# dtype: object

# %%
# Out:
#       Cod.Car.Sec Aprobado  Anho.Firma  Primer.Par  Segundo.Par  AOT  \
# 4455   CIV-PLS13         N           0           7            0    0
# 4456   MCT-PLS13         S        2017          18           15    0
# 4457   CIV-PLS13         N           0          13            0    0
# 4458   CIV-PLS13         N           0           0            0    0
# 4459   IND-PLS13         N           0           4            8    0
# ...           ...      ...         ...         ...          ...  ...
# 17432  CIV-PLS13         N           0           9           11    3
# 17433  CIV-PLS13         N        2019          12           20    3
# 17434  CIV-PLS13         N           0           0            0    2
# 17435  CIV-PLS13         S        2019          22           26    8
# 17436  CIV-PLS13         N        2019           9           22    5
#
#        Primer.Rec  Segundo.Rec Nota.Final
# 4455            0            0        NaN
# 4456            0            0       1F-2
# ...

# %%
ndf = pd.read_csv('DatosfiltradosII.csv', header = 0)

# %%
ndf['Aprobado']=np.where(ndf.Aprobado=='N',0,ndf.Aprobado)

# %%
ndf
# Out:
#       Unnamed: 0 Cod.Car.Sec  Aprobado  Anho.Firma  Primer.Par  Segundo.Par  \
# 0              0  CIV-PLS13          0           0           7            0
# 1              1  MCT-PLS13          1        2017          18           15
# 2              2  CIV-PLS13          0           0          13            0
# 3              3  CIV-PLS13          0           0           0            0
# 4              4  IND-PLS13          0           0           4            8
# ...          ...         ...       ...         ...         ...          ...
# 1892        1892  CIV-PLS13          0           0           9           11
# 1893        1893  CIV-PLS13          0        2019          12           20
# 1894        1894  CIV-PLS13          0           0           0            0
# 1895        1895  CIV-PLS13          1        2019          22           26
# 1896        1896  CIV-PLS13          0        2019           9           22
#
#       AOT  Primer.Rec  Segundo.Rec Nota.Final
# ...

# %%
ndf['Aprobado']=np.where(ndf.Aprobado=='S',1,ndf.Aprobado)

# %%
ndf.to_csv('DatosfiltradosII.csv')

# %%
ndf['Aprobado']=pd.to_numeric(ndf['Aprobado'])

# %%
ndf.dtypes
# Out:
# Cod.Car.Sec    object
# Aprobado        int64
# Anho.Firma      int64
# Primer.Par      int64
# Segundo.Par     int64
# AOT             int64
# Primer.Rec      int64
# Segundo.Rec     int64
# Nota.Final     object
# dtype: object

# %%
ndf=ndf.drop(columns='Unnamed: 0')

# %%
ndf['Nota.Final']=ndf['Nota.Final'].to_string()

# %%
for x in range(1897):
    ndf['Nota.Final'].values[x]= str(ndf['Nota.Final'].values[x]).split(",")[-1].split("-")[-1]

# %%
print(ndf['Nota.Final'].values[0])
# Out:
# nan
